# %% [markdown]
# This *Jupyter Notebook* contains the code (UNIX-based shell commands and python scripts) needed to install Tensorflow's official *Object Detection API* locally or on a hosted environment on the cloud. Please execute all these instructions in order.
#
# Also, it includes the command to mount a Google Drive Unit to the execution environment, so as to be able to access files in it with UNIX-based shell commands.

# %%
# Mounts the Google Drive Unit to be able to access it as a file system.
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# !pip install --user Cython
# !pip install --user contextlib2
# !pip install --user pillow
# !pip install --user lxml
# !pip install --user jupyter
# !pip install --user matplotlib

# %%
# !git clone https://github.com/cocodataset/cocoapi.git

# %%
cd /content/cocoapi/PythonAPI/

# %%
# !make

# %%
cd /content/

# %%
# !git clone https://github.com/tensorflow/models.git

# %%
cd /content/cocoapi/PythonAPI/

# %%
cp -r pycocotools /content/models/research/

# %%
cd /content/

# %%
# From tensorflow/models/research/
# !wget -O protobuf.zip https://github.com/google/protobuf/releases/download/v3.0.0/protoc-3.0.0-linux-x86_64.zip
# !unzip protobuf.zip

# %%
cd /content/models/research/

# %%
# !../../bin/protoc object_detection/protos/*.proto --python_out=.

# %%
# !python setup.py build
# !python setup.py install

# %%
import os
os.environ['PYTHONPATH'] = '/env/python;/content/models/research:/content/models/research/slim'

# %%
# Testing the installation
# !python ./object_detection/builders/model_builder_test.py
